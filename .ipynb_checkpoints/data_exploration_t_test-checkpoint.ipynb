# %%
import pandas as pd
import os
from scipy import stats
import matplotlib.pyplot as plt

# %%
folder_path = 'data'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Everyday\\Desktop\\HPI\\ss24\\ds4w-user-identification'

# %%
accelerometer1 = pd.read_csv(os.path.join(folder_path, 'nick1', 'ACG.csv'),sep=';')
gyroscope1 = pd.read_csv(os.path.join(folder_path, 'nick1','GYRO.csv'),sep=';')
accelerometer1.rename(columns={'x':'accelerometer_x','y':'accelerometer_y','z':'accelerometer_z'}, inplace=True)
gyroscope1.rename(columns={'x':'gyroscope_x','y':'gyroscope_y','z':'gyroscope_z'}, inplace=True)

# %%
accelerometer2 = pd.read_csv(os.path.join(folder_path, 'nick2', 'ACG.csv'),sep=';')
gyroscope2 = pd.read_csv(os.path.join(folder_path, 'nick2','GYRO.csv'),sep=';')
accelerometer2.rename(columns={'x':'accelerometer_x','y':'accelerometer_y','z':'accelerometer_z'}, inplace=True)
gyroscope2.rename(columns={'x':'gyroscope_x','y':'gyroscope_y','z':'gyroscope_z'}, inplace=True)

# %%
accelerometer3 = pd.read_csv(os.path.join(folder_path, 'till1', 'ACG.csv'),sep=';')
gyroscope3 = pd.read_csv(os.path.join(folder_path, 'till1','GYRO.csv'),sep=';')
accelerometer3.rename(columns={'x':'accelerometer_x','y':'accelerometer_y','z':'accelerometer_z'}, inplace=True)
gyroscope3.rename(columns={'x':'gyroscope_x','y':'gyroscope_y','z':'gyroscope_z'}, inplace=True)

# %%
len(accelerometer1), len(gyroscope1), len(accelerometer2), len(gyroscope2) , len(accelerometer3), len(gyroscope3)
# Out:
# (243238, 243235, 231522, 231517, 227509, 227507)

# %%
mean_accelerometer1 = accelerometer1[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']].mean()
mean_gyroscope1 = gyroscope1[['gyroscope_x', 'gyroscope_y', 'gyroscope_z']].mean()
mean_accelerometer2 = accelerometer2[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']].mean()
mean_gyroscope2 = gyroscope2[['gyroscope_x', 'gyroscope_y', 'gyroscope_z']].mean()
mean_accelerometer3 = accelerometer3[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']].mean()
mean_gyroscope3 = gyroscope3[['gyroscope_x', 'gyroscope_y', 'gyroscope_z']].mean()
walk1 = pd.concat([mean_accelerometer1, mean_gyroscope1])
walk2 = pd.concat([mean_accelerometer2, mean_gyroscope2])
walk3 = pd.concat([mean_accelerometer3, mean_gyroscope3])

# %%
t_stat, p_val = stats.ttest_ind(walk2, walk3)
print(f'T-statistic: {t_stat}')
print(f'P-value: {p_val}')
# Out:
# T-statistic: 1.5146918907906666
# P-value: 0.16079940156575445

# %%
walk1 ,walk2, walk3
# Out:
# (accelerometer_x    0.059877
#  accelerometer_y    9.893168
#  accelerometer_z   -1.070289
#  gyroscope_x       -0.052068
#  gyroscope_y        0.004664
#  gyroscope_z       -0.065741
#  dtype: float64,
#  accelerometer_x    0.729000
#  accelerometer_y    9.562022
#  accelerometer_z   -0.922400
#  gyroscope_x       -0.121558
#  gyroscope_y        0.100786
#  gyroscope_z       -0.085148
#  dtype: float64,
#  accelerometer_x    0.613332
#  accelerometer_y   -9.305886
#  accelerometer_z   -2.104435
#  gyroscope_x       -0.122387
#  gyroscope_y       -0.094447
#  gyroscope_z       -0.023080
#  dtype: float64)

# %%
walk1.mean(), walk2.mean()
# Out:
# (1.4616017083365478, 1.5437837394935296)

# %% [markdown]
# Just calculating the mean over the 5 different values get 0-devide, bc values are too close to each other

# %%
t_stat, p_val = stats.ttest_ind(walk1.mean(), walk2.mean())
print(f'T-statistic: {t_stat}')
print(f'P-value: {p_val}')
# Out:
# T-statistic: nan
# P-value: nan
# C:\Users\Everyday\AppData\Local\Temp\ipykernel_15896\1636313119.py:1: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_val = stats.ttest_ind(walk1.mean(), walk2.mean())
# c:\Users\Everyday\anaconda3\envs\cv\lib\site-packages\scipy\stats\_stats_py.py:1253: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# c:\Users\Everyday\anaconda3\envs\cv\lib\site-packages\scipy\stats\_stats_py.py:1253: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero

# %%
stat, p = stats.levene(walk1, walk2)

# %%
print(f'Statistic: {stat}')
print(f'p-value: {p}')
# Out:
# Statistic: 0.0007852234007611178
# p-value: 0.9781960746700792

# %%
merged2 = pd.merge(accelerometer1, gyroscope1, on='t_Android',how='inner')

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(accelerometer1[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']], bins=10, alpha=0.5, label='accelerometer1')
plt.hist(accelerometer2[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']], bins=10, alpha=0.5, label='accelerometer2')
plt.legend(loc='upper right')
plt.title('Histogram of accelerometer1 and accelerometer2')

plt.subplot(1, 2, 2)
plt.boxplot([accelerometer1[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']].values.flatten(), accelerometer2[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']].values.flatten()], labels=['accelerometer1', 'accelerometer2'])
plt.title('Boxplot of accelerometer1 and accelerometer2')

plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(accelerometer1[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']])
plt.subplot(1, 2, 2)
plt.plot(accelerometer2[['accelerometer_x', 'accelerometer_y', 'accelerometer_z']])
plt.show()

# %%
(merged2.t_Android.max() - merged2.t_Android.min())/ len(merged2)
# Out:
# 2215612.874183403

# %%
(merged2.t_unix_x.max(), merged2.t_unix_x.min(), merged2.t_unix_y.max(), merged2.t_unix_y.min())
# Out:
# (1714829434716, 1714828895885, 1714829434716, 1714828895885)

# %%
len(merged2)/18
# Out:
# 13513.055555555555
